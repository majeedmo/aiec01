# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
model_endpoint = "accounts/majeedmo-8n5w6yco206/deployments/qb6oudta"

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# **Answer (in the spirit of folklore and some science)**
# Because the classic tongue‑twister has more flavor than facts, the “real” answer is a blend of mythology, a bit of biology, and a whole lot of imagination.
#
# ---
#
# ### 1.  The mythic claim
# > *“A wood‑chuck would chuck as much wood as a wood‑chuck could if a wood‑chuck could chuck wood.”*
#
# No one ever measured it, but the phrase is meant to amuse and to be repeated exactly—so the *amount* is deliberately ambiguous.
#
# ---
#
# ### 2.  What scientists actually found
# In 1988, wildlife biologist **Richard Thomas** (of the U.S. Fish and Wildlife Service) did a tongue‑in‑cheek calculation to satisfy a local news story. He estimated that a woodchuck could move **approximately 700 pounds (about 320 kg)** of dirt in a burrow, and since they are good diggers, by extension he joked that a chuck might shift that *same* weight of wood.
#
# **Quick TL;DR:**
# - **700 lb** (≈ 320 kg) of wood—if the woodchuck actually dug it up and moved it.
#
# ---
#
# ### 3.  A playful “volume” version
# If you’re after volume, a typical woodchuck burrows roughly **0.15 cubic meters** of soil per day. Converting that to a chunk of pine (density ~ 0.5 g/cm³) gives something like **60 cubic feet** of wood—a figure that loosely aligns with the “700‑lb” estimate.
#
# ---
#
# ### 4.  All in all…
# - **Pure folklore:** “As much as it can!”
# - **Science‑inspired estimate:** ~ **700 lb (320 kg)** or about **60 cubic feet** of wood.
#
# So, if you’re wondering *how much* a woodchuck *could* chuck *if* it could chuck wood, the playful answer is: **“All the wood it can handle.”** Whether that’s 700 lb or more depends on whether you measure in weight, volume, or just enjoy the whimsical rhythm of the tongue‑twister.

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 25)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Response 21: A woodchuck would chuck as much wood as a woodchuck could ch...
# Response 15: The classic answer is that a woodchuck *could* chuck *as muc...
# Response 17: Ah, the age‑old riddle of the chucking chuck! While in reali...
# Response 2: A classic tongue‑twister, indeed! The most common humorous a...
# Response 10: A classic tongue‑twister trickster! The folklore answer usua...
# Response 18: A classic tongue‑twister with no one right answer! The most ...
# Response 6: In a playful twist on the classic tongue‑twister, the folklo...
# Response 4: The classic tongue‑twister has no scientific answer, but the...
# Response 19: **Answer:**
#
# In the whimsical world of the tongue‑twister, a...
# Response 13: Ah, the classic tongue‑twister! While no one has actually we...
# Response 1: **How much wood could a wood‑chuck chuck if a wood‑chuck cou...
# Response 22: If a woodchuck could actually chuck wood, the playful answer...
# Response 7: Oh, that age‑old riddle! The truth is, it’s all a bit of pla...
# Response 12: Ah, the age‑old “woodchuck” riddle gets a bit tricky when yo...
# Response 24: **Classic Answer (and a little science)**
# “In an idealized...
# Response 8: Sure thing! Here’s a fun, slightly rhyming take on the class...
# Response 23: A classic tongue‑twister, not an actual species of wood‑chuc...
# Response 11: If a wood‑chuck could *actually* chuck wood, the folklore es...
# Response 9: The old tongue‑twister is just that—a tongue‑twister!  In re...
# Response 3: **Answer (Request 3)**
#
# As the classic tongue‑twister turns ...
# Response 14: **Answer (the classic tongue‑twister version)**
#
# > *“A wood‑...
# Response 16: The tongue‑twister isn’t asking for a hard‑science answer – ...
# Response 20: Here are **20 different takes** on the classic tongue‑twiste...
# Response 5: **Short answer:** About **700 pounds** (≈ 300 kg) of wood – ...
